# %%
# !pip install pandas_profiling
# Out:
# Collecting pandas_profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#      |████████████████████████████████| 262 kB 1.2 MB/s eta 0:00:01
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (2.11.3)
# Requirement already satisfied: requests>=2.24.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (2.27.1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.21.5)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 7.2 MB/s ta 0:00:011
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.4.2)
# Requirement already satisfied: joblib~=1.1.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.1.0)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (3.5.1)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp39-cp39-macosx_10_13_x86_64.whl (694 kB)
#      |████████████████████████████████| 694 kB 6.0 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.48.2 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (4.64.0)
# Collecting markupsafe~=2.1.1
#   Downloading MarkupSafe-2.1.1-cp39-cp39-macosx_10_9_x86_64.whl (13 kB)
# Requirement already satisfied: scipy>=1.4.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.7.3)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 2.2 MB/s eta 0:00:01
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: networkx>=2.4 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.4.0)
# Requirement already satisfied: Pillow in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (9.0.1)
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      |████████████████████████████████| 812 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: cycler>=0.10 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas_profiling) (4.1.1)
# Requirement already satisfied: six>=1.5 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: PyWavelets in /Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.3.0)
# Building wheels for collected packages: htmlmin, imagehash
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=165d9a5b2c23a458e6b50f6a174902d3aebd9552669892e9bf747b90be615f04
#   Stored in directory: /Users/rianrachmanto/Library/Caches/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
#   Building wheel for imagehash (setup.py) ... done
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295206 sha256=215a0e921856c1988ae0df6c51b5e5138465dbff4270865decf6f20238ead1fd
#   Stored in directory: /Users/rianrachmanto/Library/Caches/pip/wheels/51/f9/a5/740af2fdb0ad1edf79aabdc41531be0b6f0b2e2be684c388cf
# Successfully built htmlmin imagehash
# Installing collected packages: tangled-up-in-unicode, multimethod, visions, markupsafe, imagehash, pydantic, phik, missingno, htmlmin, pandas-profiling
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# Successfully installed htmlmin-0.1.12 imagehash-4.2.1 markupsafe-2.1.1 missingno-0.5.1 multimethod-1.8 pandas-profiling-3.2.0 phik-0.12.2 pydantic-1.9.2 tangled-up-in-unicode-0.2.0 visions-0.7.4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling
import pickle
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 5 import pandas_profiling
#       6 import pickle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/__init__.py:6, in <module>
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/controller/pandas_decorator.py:4, in <module>
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/profile_report.py:27, in <module>
#      25 from pandas_profiling.report.presentation.core import Root
#      26 from pandas_profiling.report.presentation.core.renderable import Renderable
# ---> 27 from pandas_profiling.report.presentation.flavours.html.templates import (
#      28     create_html_assets,
#      29 )
#      30 from pandas_profiling.serialize_report import SerializeReport
#      31 from pandas_profiling.utils.dataframe import hash_dataframe
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/html/__init__.py:1, in <module>
# ----> 1 from pandas_profiling.report.presentation.flavours.html.alerts import HTMLAlerts
#       2 from pandas_profiling.report.presentation.flavours.html.collapse import HTMLCollapse
#       3 from pandas_profiling.report.presentation.flavours.html.container import HTMLContainer
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/html/alerts.py:2, in <module>
#       1 from pandas_profiling.report.presentation.core.alerts import Alerts
# ----> 2 from pandas_profiling.report.presentation.flavours.html import templates
#       5 class HTMLAlerts(Alerts):
#       6     def render(self) -> str:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/html/templates.py:5, in <module>
#       2 import shutil
#       3 from pathlib import Path
# ----> 5 import jinja2
#       7 from pandas_profiling.config import Settings, Theme
#       8 from pandas_profiling.report.formatters import fmt, fmt_badge, fmt_numeric, fmt_percent
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/__init__.py:12, in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/environment.py:25, in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/defaults.py:3, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/filters.py:13, in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      15 from ._compat import abc
#      16 from ._compat import imap
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (/Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages/markupsafe/__init__.py)

# %%
df=pd.read_csv('Placement_Data_Full_Class.csv')

# %%
df.head(10)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6      M  55.00   Others  49.80   Others   Science     67.25
# 6      7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7      8      M  82.00  Central  64.00  Central   Science     66.00
# 8      9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9     10      M  58.00  Central  70.00  Central  Commerce     61.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5   Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6  Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7   Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0
# 8  Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0
# 9  Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed       NaN

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 import pandas_profiling
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/__init__.py:6, in <module>
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/controller/pandas_decorator.py:4, in <module>
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/profile_report.py:27, in <module>
#      25 from pandas_profiling.report.presentation.core import Root
#      26 from pandas_profiling.report.presentation.core.renderable import Renderable
# ---> 27 from pandas_profiling.report.presentation.flavours.html.templates import (
#      28     create_html_assets,
#      29 )
#      30 from pandas_profiling.serialize_report import SerializeReport
#      31 from pandas_profiling.utils.dataframe import hash_dataframe
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/html/__init__.py:1, in <module>
# ----> 1 from pandas_profiling.report.presentation.flavours.html.alerts import HTMLAlerts
#       2 from pandas_profiling.report.presentation.flavours.html.collapse import HTMLCollapse
#       3 from pandas_profiling.report.presentation.flavours.html.container import HTMLContainer
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/html/alerts.py:2, in <module>
#       1 from pandas_profiling.report.presentation.core.alerts import Alerts
# ----> 2 from pandas_profiling.report.presentation.flavours.html import templates
#       5 class HTMLAlerts(Alerts):
#       6     def render(self) -> str:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/html/templates.py:5, in <module>
#       2 import shutil
#       3 from pathlib import Path
# ----> 5 import jinja2
#       7 from pandas_profiling.config import Settings, Theme
#       8 from pandas_profiling.report.formatters import fmt, fmt_badge, fmt_numeric, fmt_percent
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/__init__.py:12, in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/environment.py:25, in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/defaults.py:3, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/jinja2/filters.py:13, in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      15 from ._compat import abc
#      16 from ._compat import imap
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (/Users/rianrachmanto/opt/anaconda3/lib/python3.9/site-packages/markupsafe/__init__.py)

# %%
report=df.profile_report(title='Campus Placement Data-Report',progress_bar=False)
report
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 report=df.profile_report(title='Campus Placement Data-Report',progress_bar=False)
#       2 report
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'
